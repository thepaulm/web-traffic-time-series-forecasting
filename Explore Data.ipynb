# %%
basepath = 'data'

# %%
import os
os.listdir(basepath)
# Out:
# ['key_1.csv',
#  'key_1.csv.zip',
#  'sample_submission_1.csv',
#  'sample_submission_1.csv.zip',
#  'train_1.csv',
#  'train_1.csv.zip']

# %% [markdown]
# # Time Series Data

# %%
import pandas as pd

# %%
data = pd.read_csv(f'{basepath}/train_1.csv')

# %%
data
# Out:
#                                                      Page  2015-07-01  \
# 0                 2NE1_zh.wikipedia.org_all-access_spider        18.0
# 1                  2PM_zh.wikipedia.org_all-access_spider        11.0
# 2                   3C_zh.wikipedia.org_all-access_spider         1.0
# 3              4minute_zh.wikipedia.org_all-access_spider        35.0
# 4       52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN
# 5                 5566_zh.wikipedia.org_all-access_spider        12.0
# 6               91Days_zh.wikipedia.org_all-access_spider         NaN
# 7                A'N'D_zh.wikipedia.org_all-access_spider       118.0
# 8                AKB48_zh.wikipedia.org_all-access_spider         5.0
# 9                ASCII_zh.wikipedia.org_all-access_spider         6.0
# 10               ASTRO_zh.wikipedia.org_all-access_spider         NaN
# 11      Ahq_e-Sports_Club_zh.wikipedia.org_all-access_...         2.0
# ...

# %%
data.columns
# Out:
# Index(['Page', '2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04',
#        '2015-07-05', '2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09',
#        ...
#        '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25', '2016-12-26',
#        '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30', '2016-12-31'],
#       dtype='object', length=551)

# %%
data[data['Page'][0] == data['Page']]
# Out:
#                                       Page  2015-07-01  2015-07-02  \
# 0  2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
#
#    2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  2015-07-08  \
# 0         5.0        13.0        14.0         9.0         9.0        22.0
#
#    2015-07-09     ...      2016-12-22  2016-12-23  2016-12-24  2016-12-25  \
# 0        26.0     ...            32.0        63.0        15.0        26.0
#
#    2016-12-26  2016-12-27  2016-12-28  2016-12-29  2016-12-30  2016-12-31
# 0        14.0        20.0        22.0        19.0        18.0        20.0
#
# [1 rows x 551 columns]

# %%
data[0:1]
# Out:
#                                       Page  2015-07-01  2015-07-02  \
# 0  2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
#
#    2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  2015-07-08  \
# 0         5.0        13.0        14.0         9.0         9.0        22.0
#
#    2015-07-09     ...      2016-12-22  2016-12-23  2016-12-24  2016-12-25  \
# 0        26.0     ...            32.0        63.0        15.0        26.0
#
#    2016-12-26  2016-12-27  2016-12-28  2016-12-29  2016-12-30  2016-12-31
# 0        14.0        20.0        22.0        19.0        18.0        20.0
#
# [1 rows x 551 columns]

# %%
data[0:10]
# Out:
#                                                 Page  2015-07-01  2015-07-02  \
# 0            2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
# 1             2PM_zh.wikipedia.org_all-access_spider        11.0        14.0
# 2              3C_zh.wikipedia.org_all-access_spider         1.0         0.0
# 3         4minute_zh.wikipedia.org_all-access_spider        35.0        13.0
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN         NaN
# 5            5566_zh.wikipedia.org_all-access_spider        12.0         7.0
# 6          91Days_zh.wikipedia.org_all-access_spider         NaN         NaN
# 7           A'N'D_zh.wikipedia.org_all-access_spider       118.0        26.0
# 8           AKB48_zh.wikipedia.org_all-access_spider         5.0        23.0
# 9           ASCII_zh.wikipedia.org_all-access_spider         6.0         3.0
#
#    2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  2015-07-08  \
# ...

# %%
data.fillna(0)
# Out:
#                                                      Page  2015-07-01  \
# 0                 2NE1_zh.wikipedia.org_all-access_spider        18.0
# 1                  2PM_zh.wikipedia.org_all-access_spider        11.0
# 2                   3C_zh.wikipedia.org_all-access_spider         1.0
# 3              4minute_zh.wikipedia.org_all-access_spider        35.0
# 4       52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         0.0
# 5                 5566_zh.wikipedia.org_all-access_spider        12.0
# 6               91Days_zh.wikipedia.org_all-access_spider         0.0
# 7                A'N'D_zh.wikipedia.org_all-access_spider       118.0
# 8                AKB48_zh.wikipedia.org_all-access_spider         5.0
# 9                ASCII_zh.wikipedia.org_all-access_spider         6.0
# 10               ASTRO_zh.wikipedia.org_all-access_spider         0.0
# 11      Ahq_e-Sports_Club_zh.wikipedia.org_all-access_...         2.0
# ...

# %%
data.shape
# Out:
# (145063, 551)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.set()

# %%
# from https://github.com/thepaulm/pyplot_examples/blob/master/Pyplot%20Examples.ipynb
def pta(*args, color_rotate=True):
    '''pta = plot them all'''
    count = len(args)
    w = 20
    h = 4 * count
    fig = plt.figure(1, figsize=(w, h))
    for i, a in enumerate(args):
        ax = fig.add_subplot(count, 1, i+1)
        if color_rotate:
            for _ in range(i):
                ax.plot([],[])
        ax.plot(a)

# %%
rindex = np.random.randint(0, data.shape[0])

# %%
npdata = data[rindex:rindex+1].fillna(0).as_matrix()

# %%
npdata.shape
# Out:
# (1, 551)

# %%
npdata = npdata.squeeze()[1:].astype('float32')

# %%
pta(npdata)

# %%
def grab_data(df, count):
    datas = []
    for a in range(count):
        ri = np.random.randint(0, df.shape[0])
        npd = df[ri:ri+1].fillna(0).as_matrix()
        npd = npd.squeeze()[1:].astype('float32')
        datas.append(npd)
    return datas

# %%
datas = grab_data(data, 5)

# %%
type(datas)
# Out:
# list

# %%
pta(*datas)

# %% [markdown]
# # Sample Submission

# %%
submission = pd.read_csv(f'{basepath}/sample_submission_1.csv')

# %%
submission[submission['Id'] == submission['Id'][1]]
# Out:
#              Id  Visits
# 1  929ed2bf52b9       0

# %%
data.shape
# Out:
# (145063, 551)

# %%
submission.shape
# Out:
# (8703780, 2)

# %%
submission.columns
# Out:
# Index(['Id', 'Visits'], dtype='object')

# %%
submission[:10]
# Out:
#              Id  Visits
# 0  bf4edcf969af       0
# 1  929ed2bf52b9       0
# 2  ff29d0f51d5c       0
# 3  e98873359be6       0
# 4  fa012434263a       0
# 5  48f1e93517a2       0
# 6  5def418fcb36       0
# 7  77bd08134351       0
# 8  5889e6dbb16f       0
# 9  5f21fef1d764       0

# %% [markdown]
# Submission File
#
# For each article and day combination (see key.csv), you must predict the web traffic. The file should contain a header and have the following format:
#
# ```
# Id,Visits
# bf4edcf969af,0
# 929ed2bf52b9,0
# ff29d0f51d5c0
# ```
# etc.
# Due to the large file size and number of rows, submissions may take a few minutes to score. Thank you for your patience.

# %%
key = pd.read_csv(f'{basepath}/key_1.csv')

# %%
key.columns
# Out:
# Index(['Page', 'Id'], dtype='object')

# %%
key[0:10]
# Out:
#                                                 Page            Id
# 0  !vote_en.wikipedia.org_all-access_all-agents_2...  bf4edcf969af
# 1  !vote_en.wikipedia.org_all-access_all-agents_2...  929ed2bf52b9
# 2  !vote_en.wikipedia.org_all-access_all-agents_2...  ff29d0f51d5c
# 3  !vote_en.wikipedia.org_all-access_all-agents_2...  e98873359be6
# 4  !vote_en.wikipedia.org_all-access_all-agents_2...  fa012434263a
# 5  !vote_en.wikipedia.org_all-access_all-agents_2...  48f1e93517a2
# 6  !vote_en.wikipedia.org_all-access_all-agents_2...  5def418fcb36
# 7  !vote_en.wikipedia.org_all-access_all-agents_2...  77bd08134351
# 8  !vote_en.wikipedia.org_all-access_all-agents_2...  5889e6dbb16f
# 9  !vote_en.wikipedia.org_all-access_all-agents_2...  5f21fef1d764

# %%
key.Page[:10].as_matrix()
# Out:
# array(['!vote_en.wikipedia.org_all-access_all-agents_2017-01-01',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-02',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-03',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-04',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-05',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-06',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-07',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-08',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-09',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-10'], dtype=object)

# %%
key['Page'][1000]
# Out:
# '.ca_ru.wikipedia.org_desktop_all-agents_2017-02-10'

# %%
key['Id'][1000]
# Out:
# 'e6c9e360a17c'

# %%
key.Page[986]
# Out:
# '.ca_ru.wikipedia.org_desktop_all-agents_2017-01-27'

# %%
data.Page[986]
# Out:
# '黑子的籃球_zh.wikipedia.org_all-access_spider'

# %%
key[1000:2000].Page.as_matrix()[0]
# Out:
# '.ca_ru.wikipedia.org_desktop_all-agents_2017-02-10'

# %%
import re

# %%
datr = re.compile('.*(\d{4}-\d{2}-\d{2})$')

# %%
keystr = key[1000:2000].Page.as_matrix()[0]

# %%
m = datr.match(keystr)

# %%
datestr = m.group(1)

# %%
keystr = keystr[0:m.start(1)-1]

# %%
keystr
# Out:
# '.ca_ru.wikipedia.org_desktop_all-agents'

# %%
data[data.Page == keystr].columns
# Out:
# Index(['Page', '2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04',
#        '2015-07-05', '2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09',
#        ...
#        '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25', '2016-12-26',
#        '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30', '2016-12-31'],
#       dtype='object', length=551)

# %%
datestr
# Out:
# '2017-02-10'

# %% [markdown]
# ## Goal is to predict first 60 days of 2017

# %%
key.Page.as_matrix()[:60]
# Out:
# array(['!vote_en.wikipedia.org_all-access_all-agents_2017-01-01',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-02',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-03',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-04',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-05',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-06',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-07',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-08',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-09',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-10',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-11',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-12',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-13',
#        '!vote_en.wikipedia.org_all-access_all-agents_2017-01-14',
# ...

# %%
key.Page.as_matrix()[61:120]
# Out:
# array(['!vote_en.wikipedia.org_all-access_spider_2017-01-02',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-03',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-04',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-05',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-06',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-07',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-08',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-09',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-10',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-11',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-12',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-13',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-14',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-15',
#        '!vote_en.wikipedia.org_all-access_spider_2017-01-16',
# ...

# %%
key.Page.as_matrix()[121:180]
# Out:
# array(['!vote_en.wikipedia.org_desktop_all-agents_2017-01-02',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-03',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-04',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-05',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-06',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-07',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-08',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-09',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-10',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-11',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-12',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-13',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-14',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-15',
#        '!vote_en.wikipedia.org_desktop_all-agents_2017-01-16',
# ...

# %%
data.columns
# Out:
# Index(['Page', '2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04',
#        '2015-07-05', '2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09',
#        ...
#        '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25', '2016-12-26',
#        '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30', '2016-12-31'],
#       dtype='object', length=551)

# %%
data.shape[0] * 60
# Out:
# 8703780

# %%
key.shape
# Out:
# (8703780, 2)

# %% [markdown]
# # Refit For Training

# %%
npdata.shape
# Out:
# (550,)

# %%
len(npdata)
# Out:
# 550

# %%
def shaper(data, timesteps, predictions):
    outdata = []
    for a in range(0, len(data) - (timesteps * predictions)):
        d = data[a:a + timesteps * predictions]
        d = d.reshape((timesteps, predictions))
        outdata.append(d)
    return np.array(outdata)

# %%
d = shaper(npdata, 1, 60)

# %%
d.shape
# Out:
# (490, 1, 60)

# %%
d[0][0]
# Out:
# array([ 104.,  111.,   96.,  123.,  106.,   91.,  100.,  108.,   84.,
#         117.,   86.,   91.,   80.,   87.,   58.,  126.,  109.,   86.,
#         149.,  158.,  117.,  127.,  121.,  105.,   94.,  119.,  119.,
#          82.,   78.,   81.,   93.,  108.,  112.,  125.,  120.,  198.,
#         307.,  188.,  133.,  178.,  128.,  123.,  121.,  119.,  129.,
#         147.,  154.,  128.,  122.,  107.,   98.,  163.,  159.,  206.,
#         173.,  158.,  192.,  153.,  121.,  171.], dtype=float32)

# %%
d[1][0]
# Out:
# array([ 111.,   96.,  123.,  106.,   91.,  100.,  108.,   84.,  117.,
#          86.,   91.,   80.,   87.,   58.,  126.,  109.,   86.,  149.,
#         158.,  117.,  127.,  121.,  105.,   94.,  119.,  119.,   82.,
#          78.,   81.,   93.,  108.,  112.,  125.,  120.,  198.,  307.,
#         188.,  133.,  178.,  128.,  123.,  121.,  119.,  129.,  147.,
#         154.,  128.,  122.,  107.,   98.,  163.,  159.,  206.,  173.,
#         158.,  192.,  153.,  121.,  171.,  216.], dtype=float32)

# %%
d = shaper(npdata, 8, 60)

# %%
d.shape
# Out:
# (70, 8, 60)

# %%
def shaperB(data, observations, predictions):
    outX = []
    outY = []
    for a in range(0, len(data) - (observations + predictions)):
        d = data[a:a + observations + predictions]
        outX.append(d[:observations])
        outY.append(d[observations:])
    outX = np.array(outX)
    outY = np.array(outY)
    outX = outX.reshape(outX.shape + (1,))
    outY = outY.reshape(outY.shape + (1,))
    return outX, outY

# %%
x, y = shaperB(npdata, 180, 60)

# %%
x.shape, y.shape
# Out:
# ((310, 180, 1), (310, 60, 1))
